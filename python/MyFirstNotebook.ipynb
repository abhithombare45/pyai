# %%
print("Hello Abhijeet! It's really Great that you started learing Data Science.");
# Out:
# Hello Abhijeet! It's really Great that you started learing Data Science.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.8 MB 5.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 33.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 27.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 79.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 9.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 107 kB 14.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 38.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
ffmpeg -i input.mp4 output.avi
# Out:
#   Cell In[3], line 1
#     ffmpeg -i input.mp4 output.avi
#               ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

# This code creates a visual representation of the grid using different colors:
#	•	White for free spaces
#	•	Black for obstacles
#	•	Green for the start position
#	•	Red for the goal position
# You can run this script to visualize the given grid layout effectively. Let me know if you’d like additional features, such as path visualization.

grid = [
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'X', 'X', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'X', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'S', 'W', 'W', 'W', 'G', 'W'],
    ['W', 'W', 'X', 'X', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
]

# Define colors for the grid
def get_color(cell):
    if cell == 'W':
        return 'white'
    elif cell == 'X':
        return 'black'
    elif cell == 'S':
        return 'green'
    elif cell == 'G':
        return 'red'

# Create visualization
fig, ax = plt.subplots()
ax.set_xticks(np.arange(len(grid[0]) + 1) - 0.5, minor=True)
ax.set_yticks(np.arange(len(grid) + 1) - 0.5, minor=True)
ax.grid(which='minor', color='black', linestyle='-', linewidth=1)
ax.tick_params(which='both', bottom=False, left=False, labelbottom=False, labelleft=False)

for i in range(len(grid)):
    for j in range(len(grid[i])):
        color = get_color(grid[i][j])
        ax.add_patch(plt.Rectangle((j, len(grid) - 1 - i), 1, 1, color=color))

plt.show()

# %%
# Moving Object 

import matplotlib.pyplot as plt
import numpy as np
import time

grid = [
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'X', 'X', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'X', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'S', 'W', 'W', 'W', 'G', 'W'],
    ['W', 'W', 'X', 'X', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'X', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
]

path = [(4, 4), (4, 5), (4, 6), (4, 7), (4, 8)]

# Define colors for the grid
def get_color(cell):
    if cell == 'W':
        return 'white'
    elif cell == 'X':
        return 'black'
    elif cell == 'S':
        return 'green'
    elif cell == 'G':
        return 'red'
    elif cell == 'P':
        return 'blue'

# Create visualization
def draw_grid(current_pos):
    fig, ax = plt.subplots()
    ax.set_xticks(np.arange(len(grid[0]) + 1) - 0.5, minor=True)
    ax.set_yticks(np.arange(len(grid) + 1) - 0.5, minor=True)
    ax.grid(which='minor', color='black', linestyle='-', linewidth=1)
    ax.tick_params(which='both', bottom=False, left=False, labelbottom=False, labelleft=False)

    for i in range(len(grid)):
        for j in range(len(grid[i])):
            cell = 'P' if (i, j) == current_pos else grid[i][j]
            color = get_color(cell)
            ax.add_patch(plt.Rectangle((j, len(grid) - 1 - i), 1, 1, color=color))

    plt.pause(0.5)
    plt.close()

for pos in path:
    draw_grid(pos)

plt.show()
